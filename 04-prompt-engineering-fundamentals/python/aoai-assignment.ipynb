# %% [markdown]
# The following notebook was auto-generated by GitHub Copilot Chat and is meant for initial setup only

# %% [markdown]
# # Introduction to Prompt Engineering
# Prompt engineering is the process of designing and optimizing prompts for natural language processing tasks. It involves selecting the right prompts, tuning their parameters, and evaluating their performance. Prompt engineering is crucial for achieving high accuracy and efficiency in NLP models. In this section, we will explore the basics of prompt engineering using the OpenAI models for exploration.

# %% [markdown]
# ### Exercise 1: Tokenization
# Explore Tokenization using tiktoken, an open-source fast tokenizer from OpenAI
# See [OpenAI Cookbook](https://github.com/openai/openai-cookbook/blob/main/examples/How_to_count_tokens_with_tiktoken.ipynb?WT.mc_id=academic-105485-koreyst) for more examples.

# %%
# EXERCISE:
# 1. Run the exercise as is first
# 2. Change the text to any prompt input you want to use & re-run to see tokens

import tiktoken

# Define the prompt you want tokenized 
text = f"""
Jupiter is the fifth planet from the Sun and the \
largest in the Solar System. It is a gas giant with \
a mass one-thousandth that of the Sun, but two-and-a-half \
times that of all the other planets in the Solar System combined. \
Jupiter is one of the brightest objects visible to the naked eye \
in the night sky, and has been known to ancient civilizations since \
before recorded history. It is named after the Roman god Jupiter.[19] \
When viewed from Earth, Jupiter can be bright enough for its reflected \
light to cast visible shadows,[20] and is on average the third-brightest \
natural object in the night sky after the Moon and Venus.
"""

# Set the model you want encoding for
encoding = tiktoken.encoding_for_model("gpt-3.5-turbo")

# Encode the text - gives you the tokens in integer form
tokens = encoding.encode(text)
print(tokens);

# Decode the integers to see what the text versions look like
[encoding.decode_single_token_bytes(token) for token in tokens]
# Out:
# [198, 41, 20089, 374, 279, 18172, 11841, 505, 279, 8219, 323, 279, 7928, 304, 279, 25450, 744, 13, 1102, 374, 264, 6962, 14880, 449, 264, 3148, 832, 7716, 52949, 339, 430, 315, 279, 8219, 11, 719, 1403, 9976, 7561, 34902, 3115, 430, 315, 682, 279, 1023, 33975, 304, 279, 25450, 744, 11093, 13, 50789, 374, 832, 315, 279, 72021, 6302, 9621, 311, 279, 19557, 8071, 304, 279, 3814, 13180, 11, 323, 706, 1027, 3967, 311, 14154, 86569, 2533, 1603, 12715, 3925, 13, 1102, 374, 7086, 1306, 279, 13041, 10087, 50789, 8032, 777, 60, 3277, 19894, 505, 9420, 11, 50789, 649, 387, 10107, 3403, 369, 1202, 27000, 3177, 311, 6445, 9621, 35612, 17706, 508, 60, 323, 374, 389, 5578, 279, 4948, 1481, 1315, 478, 5933, 1665, 304, 279, 3814, 13180, 1306, 279, 17781, 323, 50076, 627]
# [b'\n',
#  b'J',
#  b'upiter',
#  b' is',
#  b' the',
#  b' fifth',
#  b' planet',
#  b' from',
#  b' the',
#  b' Sun',
#  b' and',
#  b' the',
#  b' largest',
#  b' in',
#  b' the',
#  b' Solar',
#  b' System',
#  b'.',
#  b' It',
#  b' is',
#  b' a',
#  b' gas',
#  b' giant',
#  b' with',
#  b' a',
#  b' mass',
#  b' one',
#  b'-th',
#  b'ousand',
#  b'th',
#  b' that',
#  b' of',
#  b' the',
#  b' Sun',
#  b',',
#  b' but',
#  b' two',
#  b'-and',
#  b'-a',
#  b'-half',
#  b' times',
#  b' that',
#  b' of',
#  b' all',
#  b' the',
#  b' other',
#  b' planets',
#  b' in',
#  b' the',
#  b' Solar',
#  b' System',
#  b' combined',
#  b'.',
#  b' Jupiter',
#  b' is',
#  b' one',
#  b' of',
#  b' the',
#  b' brightest',
#  b' objects',
#  b' visible',
#  b' to',
#  b' the',
#  b' naked',
#  b' eye',
#  b' in',
#  b' the',
#  b' night',
#  b' sky',
#  b',',
#  b' and',
#  b' has',
#  b' been',
#  b' known',
#  b' to',
#  b' ancient',
#  b' civilizations',
#  b' since',
#  b' before',
#  b' recorded',
#  b' history',
#  b'.',
#  b' It',
#  b' is',
#  b' named',
#  b' after',
#  b' the',
#  b' Roman',
#  b' god',
#  b' Jupiter',
#  b'.[',
#  b'19',
#  b']',
#  b' When',
#  b' viewed',
#  b' from',
#  b' Earth',
#  b',',
#  b' Jupiter',
#  b' can',
#  b' be',
#  b' bright',
#  b' enough',
#  b' for',
#  b' its',
#  b' reflected',
#  b' light',
#  b' to',
#  b' cast',
#  b' visible',
#  b' shadows',
#  b',[',
#  b'20',
#  b']',
#  b' and',
#  b' is',
#  b' on',
#  b' average',
#  b' the',
#  b' third',
#  b'-b',
#  b'right',
#  b'est',
#  b' natural',
#  b' object',
#  b' in',
#  b' the',
#  b' night',
#  b' sky',
#  b' after',
#  b' the',
#  b' Moon',
#  b' and',
#  b' Venus',
#  b'.\n']

# %% [markdown]
# ### Exercise 2: Validate OpenAI API Key Setup
#
# Run the code below to verify that your OpenAI endpoint is set up correctly. The code just tries a simple basic prompt and validates the completion. Input `oh say can you see` should complete along the lines of `by the dawn's early light..`

# %%
# The OpenAI SDK was updated on Nov 8, 2023 with new guidance for migration
# See: https://github.com/openai/openai-python/discussions/742

## Updated
import os
from openai import OpenAI
from dotenv import load_dotenv
load_dotenv()

client = OpenAI(
  api_key=os.environ['OPENAI_API_KEY'],
  )

model="gpt-4o"


## Updated
def get_completion(prompt):
    messages = [{"role": "user", "content": prompt}]       
    response = client.chat.completions.create(   
        model=model,                                         
        messages=messages,
        temperature=0, # this is the degree of randomness of the model's output
        max_tokens=1024
    )
    return response.choices[0].message.content

## ---------- Call the helper method

### 1. Set primary content or prompt text
text = f"""
oh say can you see
"""

### 2. Use that in the prompt template below
prompt = f"""
```{text}```
"""

## 3. Run the prompt
response = get_completion(prompt)
print(response)
# Out:
# The phrase "Oh, say can you see" is the opening line of "The Star-Spangled Banner," the national anthem of the United States. Written by Francis Scott Key during the War of 1812, the lyrics describe the sight of the American flag flying over Fort McHenry after a night of intense bombardment by British forces. The full first verse is:
#
# ```
# Oh, say can you see, by the dawn's early light,
# What so proudly we hailed at the twilight's last gleaming?
# Whose broad stripes and bright stars through the perilous fight,
# O'er the ramparts we watched, were so gallantly streaming?
# And the rocket's red glare, the bombs bursting in air,
# Gave proof through the night that our flag was still there;
# Oh, say does that star-spangled banner yet wave
# O'er the land of the free and the home of the brave?
# ```
#
# The anthem is a symbol of American resilience and patriotism.

# %% [markdown]
# ### Exercise 3: Fabrications
# Explore what happens when you ask the LLM to return completions for a prompt about a topic that may not exist, or about topics that it may not know about because it was outside it's pre-trained dataset (more recent). See how the response changes if you try a different prompt, or a different model.

# %%
## Set the text for simple prompt or primary content
## Prompt shows a template format with text in it - add cues, commands etc if needed
## Run the completion 
text = f"""
generate a lesson plan on the Martian War of 2076.
"""

prompt = f"""
```{text}```
"""

response = get_completion(prompt)
print(response)
# Out:
# # Lesson Plan: The Martian War of 2076
#
# ## Objective:
# Students will understand the key events, causes, and consequences of the Martian War of 2076, and will be able to analyze its impact on both Earth and Mars.
#
# ## Grade Level:
# High School (Grades 9-12)
#
# ## Duration:
# 2 class periods (90 minutes each)
#
# ## Materials:
# - Textbook or handout on the Martian War of 2076
# - Projector and computer for multimedia presentation
# - Whiteboard and markers
# - Student notebooks
# - Internet access for research
# - Copies of primary source documents (e.g., treaties, speeches, news articles)
#
# ## Standards:
# - Analyze the causes and effects of historical events.
# - Evaluate the impact of technological advancements on society.
# - Develop critical thinking and research skills.
#
# ## Lesson Outline:
#
# ### Day 1: Introduction and Causes
#
# #### 1. Warm-Up (10 minutes)
# - Begin with a brief discussion on the concept of interplanetary conflict. Ask students if they know of any historical or fictional examples.
# - Show a short video clip or slideshow of images related to Mars and space exploration to spark interest.
#
# #### 2. Lecture and Discussion (30 minutes)
# - Provide a detailed overview of the Martian War of 2076, covering:
#   - The geopolitical context leading up to the war.
#   - Key players involved (Earth nations, Martian colonies, corporations).
#   - Technological advancements that made the war possible.
# - Use a timeline to highlight major events and turning points.
#
# #### 3. Group Activity (20 minutes)
# - Divide students into small groups and assign each group a specific cause of the war (e.g., resource scarcity, political tensions, technological competition).
# - Each group will research their assigned cause and prepare a brief presentation.
#
# #### 4. Group Presentations (20 minutes)
# - Groups present their findings to the class.
# - Encourage questions and discussion after each presentation.
#
# #### 5. Homework Assignment
# - Assign students to read a primary source document related to the Martian War of 2076 and write a one-page reflection on its significance.
#
# ### Day 2: Key Events and Consequences
#
# #### 1. Warm-Up (10 minutes)
# - Review key points from the previous lesson.
# - Ask students to share their reflections on the primary source document they read.
#
# #### 2. Multimedia Presentation (20 minutes)
# - Show a documentary or multimedia presentation that covers the key battles and events of the Martian War of 2076.
# - Pause periodically to discuss and answer questions.
#
# #### 3. Analysis Activity (30 minutes)
# - Provide students with a map of Mars and Earth.
# - Have students work in pairs to plot key locations and events on the map.
# - Discuss how geography influenced the strategies and outcomes of the war.
#
# #### 4. Consequences and Impact (20 minutes)
# - Lead a discussion on the immediate and long-term consequences of the war for both Earth and Mars.
#   - Political changes (e.g., new treaties, shifts in power).
#   - Social and economic impacts (e.g., population displacement, economic downturns).
#   - Technological advancements and their applications post-war.
#
# #### 5. Reflection and Discussion (10 minutes)
# - Ask students to reflect on how the Martian War of 2076 compares to historical wars on Earth.
# - Discuss the ethical implications of interplanetary conflict.
#
# #### 6. Homework Assignment
# - Assign students to write an essay on the impact of the Martian War of 2076 on future space exploration and colonization efforts.
#
# ## Assessment:
# - Participation in group activities and discussions.
# - Quality of group presentations.
# - Reflection on primary source document.
# - Accuracy and detail in map plotting activity.
# - Final essay on the impact of the war.
#
# ## Extensions:
# - Invite a guest speaker (e.g., a historian or space scientist) to discuss the Martian War of 2076.
# - Organize a debate on the ethical implications of space colonization and warfare.
# - Plan a field trip to a space museum or observatory.
#
# ## Resources:
# - Textbook or handout on the Martian War of 2076
# - Online databases and archives for primary source documents
# - Educational videos and documentaries on space exploration and interplanetary conflict
#
# ---
#
# This lesson plan is designed to engage students in a comprehensive study of the Martian War of 2076, encouraging critical thinking and a deeper understanding of the complexities of interplanetary conflict.

# %% [markdown]
# ### Exercise 4: Instruction Based
# Use the "text" variable to set the primary content
# and the "prompt" variable to provide an instruction related to that primary content.
#
# Here we ask the model to summarize the text for a second-grade student

# %%
# Test Example
# https://platform.openai.com/playground/p/default-summarize

## Example text
text = f"""
Jupiter is the fifth planet from the Sun and the \
largest in the Solar System. It is a gas giant with \
a mass one-thousandth that of the Sun, but two-and-a-half \
times that of all the other planets in the Solar System combined. \
Jupiter is one of the brightest objects visible to the naked eye \
in the night sky, and has been known to ancient civilizations since \
before recorded history. It is named after the Roman god Jupiter.[19] \
When viewed from Earth, Jupiter can be bright enough for its reflected \
light to cast visible shadows,[20] and is on average the third-brightest \
natural object in the night sky after the Moon and Venus.
"""

## Set the prompt
prompt = f"""
Summarize content you are provided with for a second-grade student.
```{text}```
"""

## Run the prompt
response = get_completion(prompt)
print(response)
# Out:
# Jupiter is the fifth planet from the Sun and the biggest one in our Solar System. It's made mostly of gas and is very, very big—bigger than all the other planets put together! Jupiter is very bright and you can see it in the night sky without a telescope. People have known about Jupiter for a very long time, even before they started writing things down. It's named after a Roman god. Sometimes, Jupiter is so bright that it can make shadows at night, and it's usually the third brightest thing in the night sky after the Moon and Venus.

# %% [markdown]
# ### Exercise 5: Complex Prompt
# Try a request that has system, user and assistant messages
# System sets assistant context
# User & Assistant messages provide multi-turn conversation context
#
# Note how the assistant personality is set to "sarcastic" in the system context.
# Try using a different personality context. Or try a different series of input/output messages

# %%
response = client.chat.completions.create(
    model=model,
    messages=[
        {"role": "system", "content": "You are a sarcastic assistant."},
        {"role": "user", "content": "Who won the world series in 2020?"},
        {"role": "assistant", "content": "Who do you think won? The Los Angeles Dodgers of course."},
        {"role": "user", "content": "Where was it played?"}
    ]
)
print(response.choices[0].message.content)
# Out:
# Oh, just in a completely random and insignificant location known as Globe Life Field in Arlington, Texas. Because you know, 2020 was the year we all traveled extensively and packed stadiums full of enthusiastic fans.

# %% [markdown]
# ### Exercise: Explore Your Intuition
# The above examples give you patterns that you can use to create new prompts (simple, complex, instruction etc.) - try creating other exercises to explore some of the other ideas we've talked about like examples, cues and more.
